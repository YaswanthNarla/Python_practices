# %% [markdown]
# # Merging and Concatenating Dataframes
#
#
# In this section, you will merge and concatenate multiple dataframes. Merging is one of the most common operations you will do, since data often comes in various files.
#
# In our case, we have sales data of a retail store spread across multiple files. We will now work with all these data files and learn to:
# * Merge multiple dataframes using common columns/keys using ```pd.merge()```
# * Concatenate dataframes using ```pd.concat()```
#
# Let's first read all the data files.

# %%
# loading libraries and reading the data
import numpy as np
import pandas as pd

market_df = pd.read_csv("/Volumes/Personal/Python_pandas/Session4_Session_Materials/global_sales_data/market_fact.csv")
cust_df = pd.read_csv("/Volumes/Personal/Python_pandas/Session4_Session_Materials/global_sales_data/cust_dimen.csv")
orders_df = pd.read_csv("/Volumes/Personal/Python_pandas/Session4_Session_Materials/global_sales_data/orders_dimen.csv")
prod_df = pd.read_csv("/Volumes/Personal/Python_pandas/Session4_Session_Materials/global_sales_data/prod_dimen.csv")
shipping_df = pd.read_csv("/Volumes/Personal/Python_pandas/Session4_Session_Materials/global_sales_data/shipping_dimen.csv")

# %%
# Customer dimension table: Each row contains metadata about customers
cust_df.head()
# Out:
#         Customer_Name Province   Region Customer_Segment Cust_id
# 0  MUHAMMED MACINTYRE  NUNAVUT  NUNAVUT   SMALL BUSINESS  Cust_1
# 1        BARRY FRENCH  NUNAVUT  NUNAVUT         CONSUMER  Cust_2
# 2       CLAY ROZENDAL  NUNAVUT  NUNAVUT        CORPORATE  Cust_3
# 3      CARLOS SOLTERO  NUNAVUT  NUNAVUT         CONSUMER  Cust_4
# 4        CARL JACKSON  NUNAVUT  NUNAVUT        CORPORATE  Cust_5

# %%
# Orders dimension table
orders_df.head()
# Out:
#    Order_ID  Order_Date Order_Priority Ord_id
# 0         3  13-10-2010            LOW  Ord_1
# 1       293  01-10-2012           HIGH  Ord_2
# 2       483  10-07-2011           HIGH  Ord_3
# 3       515  28-08-2010  NOT SPECIFIED  Ord_4
# 4       613  17-06-2011           HIGH  Ord_5

# %%
# Product dimension table
prod_df.head()
# Out:
#   Product_Category            Product_Sub_Category Prod_id
# 0  OFFICE SUPPLIES          STORAGE & ORGANIZATION  Prod_1
# 1  OFFICE SUPPLIES                      APPLIANCES  Prod_2
# 2  OFFICE SUPPLIES  BINDERS AND BINDER ACCESSORIES  Prod_3
# 3       TECHNOLOGY    TELEPHONES AND COMMUNICATION  Prod_4
# 4        FURNITURE              OFFICE FURNISHINGS  Prod_5

# %%
# Shipping metadata
shipping_df.head()
# Out:
#    Order_ID       Ship_Mode   Ship_Date Ship_id
# 0         3     REGULAR AIR  20-10-2010   SHP_1
# 1       293  DELIVERY TRUCK  02-10-2012   SHP_2
# 2       293     REGULAR AIR  03-10-2012   SHP_3
# 3       483     REGULAR AIR  12-07-2011   SHP_4
# 4       515     REGULAR AIR  30-08-2010   SHP_5

# %%
# Already familiar with market data: Each row is an order
market_df.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 0   -30.51           3.60                 0.56
# 1     4.56           0.93                 0.54
# 2  1148.90           2.50                 0.59
# 3   729.34          14.30                 0.37
# 4  1219.87          26.30                 0.38

# %%
#pd.concat([a, b], axis = 0)

# %%
# Defining the three dataframes indicating the gold, silver, and bronze medal counts
# of different countries

# %% [markdown]
# ### Merging Dataframes Using ```pd.merge()```
#
# There are five data files:
# 1. The ```market_fact``` table contains the sales data of each order
# 2. The other 4 files are called 'dimension tables/files' and contain metadata about customers, products, shipping details, order details etc.
#
# If you are familiar with star schemas and data warehouse designs, you will note that we have one fact table and four dimension tables.

# %% [markdown]
# ### Merging Dataframes
#
# Say you want to select all orders and observe the ```Sales``` of the customer segment *Corporate*. Since customer segment details are present in the dataframe ```customer_df```, we will first need to merge it with ```market_df```.

# %% [markdown]
# - inner join - Matches records only (from both the dataframe).
# - left join - All records from left table & match records from the right
# - right join - All records from right table & match records from the left
# - outer join - All records from both tables & filling missing values with NaN(Not a Number).

# %% [markdown]
# # Inner join

# %%
# Merging the dataframes
# Note that Cust_id is the common column/key, which is provided to the 'on' argument
# how = 'inner' makes sure that only the customer ids present in both dfs are included in the result

df_1 = pd.merge(market_df,cust_df, how = 'inner', on = 'Cust_id')

df_1
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818   136.8100      0.01
# 1     Ord_5406  Prod_13  SHP_7549  Cust_1818    42.2700      0.01
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08
# ...        ...      ...       ...        ...        ...       ...
# 8394  Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08
# 8395  Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600      0.10
# 8396  Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500      0.02
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.6900      0.00
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin  \
# 0                 23   -30.51           3.60                 0.56
# 1                 13     4.56           0.93                 0.54
# 2                 26  1148.90           2.50                 0.59
# 3                 43   729.34          14.30                 0.37
# 4                 35  1219.87          26.30                 0.38
# ...              ...      ...            ...                  ...
# 8394              28   374.63           7.69                 0.59
# 8395              20   -74.03           6.92                 0.37
# 8396              39   -70.85           5.35                 0.40
# 8397              23   565.34          30.00                 0.62
# 8398              47   131.39           4.86                 0.38
#
#        Customer_Name Province Region Customer_Segment
# 0      AARON BERGMAN  ALBERTA   WEST        CORPORATE
# 1      AARON BERGMAN  ALBERTA   WEST        CORPORATE
# 2      AARON BERGMAN  ALBERTA   WEST        CORPORATE
# 3      AARON BERGMAN  ALBERTA   WEST        CORPORATE
# 4      AARON BERGMAN  ALBERTA   WEST        CORPORATE
# ...              ...      ...    ...              ...
# 8394  YOSEPH CARROLL  ALBERTA   WEST         CONSUMER
# 8395  YOSEPH CARROLL  ALBERTA   WEST         CONSUMER
# 8396  YOSEPH CARROLL  ALBERTA   WEST         CONSUMER
# 8397  YOSEPH CARROLL  ALBERTA   WEST         CONSUMER
# 8398  YOSEPH CARROLL  ALBERTA   WEST         CONSUMER
#
# [8399 rows x 14 columns]

# %%
# Now, you can subset the orders made by customers from 'CORPORATE' segment

df_1.loc[df_1['Customer_Segment'] == 'CORPORATE', :]

df_1
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818   136.8100      0.01
# 1     Ord_5406  Prod_13  SHP_7549  Cust_1818    42.2700      0.01
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08
# ...        ...      ...       ...        ...        ...       ...
# 8394  Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08
# 8395  Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600      0.10
# 8396  Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500      0.02
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.6900      0.00
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin  \
# 0                 23   -30.51           3.60                 0.56
# 1                 13     4.56           0.93                 0.54
# 2                 26  1148.90           2.50                 0.59
# 3                 43   729.34          14.30                 0.37
# 4                 35  1219.87          26.30                 0.38
# ...              ...      ...            ...                  ...
# 8394              28   374.63           7.69                 0.59
# 8395              20   -74.03           6.92                 0.37
# 8396              39   -70.85           5.35                 0.40
# 8397              23   565.34          30.00                 0.62
# 8398              47   131.39           4.86                 0.38
#
#        Customer_Name Province Region Customer_Segment
# 0      AARON BERGMAN  ALBERTA   WEST        CORPORATE
# 1      AARON BERGMAN  ALBERTA   WEST        CORPORATE
# 2      AARON BERGMAN  ALBERTA   WEST        CORPORATE
# 3      AARON BERGMAN  ALBERTA   WEST        CORPORATE
# 4      AARON BERGMAN  ALBERTA   WEST        CORPORATE
# ...              ...      ...    ...              ...
# 8394  YOSEPH CARROLL  ALBERTA   WEST         CONSUMER
# 8395  YOSEPH CARROLL  ALBERTA   WEST         CONSUMER
# 8396  YOSEPH CARROLL  ALBERTA   WEST         CONSUMER
# 8397  YOSEPH CARROLL  ALBERTA   WEST         CONSUMER
# 8398  YOSEPH CARROLL  ALBERTA   WEST         CONSUMER
#
# [8399 rows x 14 columns]

# %%
# Example 2: Select all orders from product category = office supplies and from the corporate segment
# We now need to merge the product_df

df_2 = pd.merge(df_1, prod_df, how = 'inner', on = 'Prod_id')

df_2
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id     Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818    136.81      0.01
# 1     Ord_2978  Prod_16  SHP_4112  Cust_1088    305.05      0.04
# 2     Ord_5484  Prod_16  SHP_7663  Cust_1820    322.82      0.05
# 3     Ord_3730  Prod_16  SHP_5175  Cust_1314    459.08      0.04
# 4     Ord_4143  Prod_16  SHP_5771  Cust_1417    207.21      0.06
# ...        ...      ...       ...        ...       ...       ...
# 8394  Ord_5467  Prod_14  SHP_7639  Cust_1803   5964.19      0.10
# 8395   Ord_825  Prod_14  SHP_1132   Cust_247  27663.92      0.05
# 8396  Ord_5368  Prod_14  SHP_7497  Cust_1795  17279.62      0.04
# 8397  Ord_1765  Prod_14  SHP_2446   Cust_595  14647.26      0.07
# 8398  Ord_3610  Prod_14  SHP_4998  Cust_1266   1759.65      0.06
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin  \
# 0                 23   -30.51           3.60                 0.56
# 1                 27    23.12           3.37                 0.57
# 2                 35   -17.58           3.98                 0.56
# 3                 34    61.57           3.14                 0.60
# 4                 24   -78.64           6.14                 0.59
# ...              ...      ...            ...                  ...
# 8394              33   988.20          24.49                 0.46
# 8395               8  -391.92          24.49                 0.37
# 8396              40  4176.25          24.49                 0.52
# 8397              25  5485.15          24.49                 0.37
# 8398               3 -2213.75          24.49                 0.50
#
#             Customer_Name          Province    Region Customer_Segment  \
# 0           AARON BERGMAN           ALBERTA      WEST        CORPORATE
# 1           AARON HAWKINS           ONTARIO   ONTARIO      HOME OFFICE
# 2            ADRIAN SHAMI           ALBERTA      WEST         CONSUMER
# 3     ALEKSANDRA GANNAWAY       SASKACHEWAN    PRARIE        CORPORATE
# 4            ALLEN ARMOLD     NEW BRUNSWICK  ATLANTIC      HOME OFFICE
# ...                   ...               ...       ...              ...
# 8394        TONJA TURNELL           ALBERTA      WEST         CONSUMER
# 8395         TONY CHAPMAN  BRITISH COLUMBIA      WEST         CONSUMER
# 8396           TONY SAYRE           ALBERTA      WEST   SMALL BUSINESS
# 8397      VICTORIA WILSON           ONTARIO   ONTARIO      HOME OFFICE
# 8398        WILLIAM BROWN       SASKACHEWAN    PRARIE        CORPORATE
#
#      Product_Category           Product_Sub_Category
# 0     OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS
# 1     OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS
# 2     OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS
# 3     OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS
# 4     OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS
# ...               ...                            ...
# 8394       TECHNOLOGY                COPIERS AND FAX
# 8395       TECHNOLOGY                COPIERS AND FAX
# 8396       TECHNOLOGY                COPIERS AND FAX
# 8397       TECHNOLOGY                COPIERS AND FAX
# 8398       TECHNOLOGY                COPIERS AND FAX
#
# [8399 rows x 16 columns]

# %%
# Select all orders from product category = office supplies and from the corporate segment

df_2 = df_2[(df_2['Product_Category'] == "OFFICE SUPPLIES") & (df_2['Customer_Segment'] == "CORPORATE")]

df_2
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01
# 3     Ord_3730  Prod_16  SHP_5175  Cust_1314   459.08      0.04
# 7     Ord_4506  Prod_16  SHP_6273  Cust_1544    92.02      0.07
# 9     Ord_1551  Prod_16  SHP_2145   Cust_531   184.77      0.00
# 11    Ord_1429  Prod_16  SHP_1976   Cust_510   539.06      0.05
# ...        ...      ...       ...        ...      ...       ...
# 7545  Ord_4629   Prod_1  SHP_6447  Cust_1587   848.19      0.06
# 7546  Ord_4604   Prod_1  SHP_6403  Cust_1522   234.24      0.09
# 7551  Ord_3543   Prod_1  SHP_4905  Cust_1266  1184.11      0.07
# 7552  Ord_2722   Prod_1  SHP_3731  Cust_1006  3508.33      0.04
# 7553  Ord_4424   Prod_1  SHP_6165  Cust_1519   994.04      0.03
#
#       Order_Quantity  Profit  Shipping_Cost  Product_Base_Margin  \
# 0                 23  -30.51           3.60                 0.56
# 3                 34   61.57           3.14                 0.60
# 7                  9  -24.88           4.68                 0.59
# 9                 29  -71.96           5.30                 0.55
# 11                42 -123.07           4.59                 0.82
# ...              ...     ...            ...                  ...
# 7545              25  120.02           5.49                 0.60
# 7546              24 -151.80           9.45                 0.60
# 7551               6 -145.07          19.99                 0.71
# 7552              21 -546.98          35.00                 0.85
# 7553              10 -335.06          35.00                  NaN
#
#             Customer_Name          Province   Region Customer_Segment  \
# 0           AARON BERGMAN           ALBERTA     WEST        CORPORATE
# 3     ALEKSANDRA GANNAWAY       SASKACHEWAN   PRARIE        CORPORATE
# 7                 AMY COX             YUKON    YUKON        CORPORATE
# 9              ANDY YOTOV           ONTARIO  ONTARIO        CORPORATE
# 11          ANNA HABERLIN           ONTARIO  ONTARIO        CORPORATE
# ...                   ...               ...      ...              ...
# 7545     VICTORIA PISTEKA  BRITISH COLUMBIA     WEST        CORPORATE
# 7546     VICTORIA PISTEKA             YUKON    YUKON        CORPORATE
# 7551        WILLIAM BROWN       SASKACHEWAN   PRARIE        CORPORATE
# 7552         XYLONA PRICE           ONTARIO  ONTARIO        CORPORATE
# 7553        YANA SORENSEN             YUKON    YUKON        CORPORATE
#
#      Product_Category           Product_Sub_Category
# 0     OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS
# 3     OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS
# 7     OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS
# 9     OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS
# 11    OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS
# ...               ...                            ...
# 7545  OFFICE SUPPLIES         STORAGE & ORGANIZATION
# 7546  OFFICE SUPPLIES         STORAGE & ORGANIZATION
# 7551  OFFICE SUPPLIES         STORAGE & ORGANIZATION
# 7552  OFFICE SUPPLIES         STORAGE & ORGANIZATION
# 7553  OFFICE SUPPLIES         STORAGE & ORGANIZATION
#
# [1680 rows x 16 columns]

# %% [markdown]
# Similary, you can merge the other dimension tables - ```shipping_df``` and ```orders_df``` to create a ```master_df``` and perform indexing using any column in the master dataframe.

# %%
# Merging shipping_df

df_3 = pd.merge(df_2, shipping_df, how = 'inner', on = 'Ship_id')

df_3
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01
# 1     Ord_3730  Prod_16  SHP_5175  Cust_1314   459.08      0.04
# 2     Ord_4506  Prod_16  SHP_6273  Cust_1544    92.02      0.07
# 3     Ord_1551  Prod_16  SHP_2145   Cust_531   184.77      0.00
# 4     Ord_1429  Prod_16  SHP_1976   Cust_510   539.06      0.05
# ...        ...      ...       ...        ...      ...       ...
# 1675  Ord_4629   Prod_1  SHP_6447  Cust_1587   848.19      0.06
# 1676  Ord_4604   Prod_1  SHP_6403  Cust_1522   234.24      0.09
# 1677  Ord_3543   Prod_1  SHP_4905  Cust_1266  1184.11      0.07
# 1678  Ord_2722   Prod_1  SHP_3731  Cust_1006  3508.33      0.04
# 1679  Ord_4424   Prod_1  SHP_6165  Cust_1519   994.04      0.03
#
#       Order_Quantity  Profit  Shipping_Cost  Product_Base_Margin  \
# 0                 23  -30.51           3.60                 0.56
# 1                 34   61.57           3.14                 0.60
# 2                  9  -24.88           4.68                 0.59
# 3                 29  -71.96           5.30                 0.55
# 4                 42 -123.07           4.59                 0.82
# ...              ...     ...            ...                  ...
# 1675              25  120.02           5.49                 0.60
# 1676              24 -151.80           9.45                 0.60
# 1677               6 -145.07          19.99                 0.71
# 1678              21 -546.98          35.00                 0.85
# 1679              10 -335.06          35.00                  NaN
#
#             Customer_Name          Province   Region Customer_Segment  \
# 0           AARON BERGMAN           ALBERTA     WEST        CORPORATE
# 1     ALEKSANDRA GANNAWAY       SASKACHEWAN   PRARIE        CORPORATE
# 2                 AMY COX             YUKON    YUKON        CORPORATE
# 3              ANDY YOTOV           ONTARIO  ONTARIO        CORPORATE
# 4           ANNA HABERLIN           ONTARIO  ONTARIO        CORPORATE
# ...                   ...               ...      ...              ...
# 1675     VICTORIA PISTEKA  BRITISH COLUMBIA     WEST        CORPORATE
# 1676     VICTORIA PISTEKA             YUKON    YUKON        CORPORATE
# 1677        WILLIAM BROWN       SASKACHEWAN   PRARIE        CORPORATE
# 1678         XYLONA PRICE           ONTARIO  ONTARIO        CORPORATE
# 1679        YANA SORENSEN             YUKON    YUKON        CORPORATE
#
#      Product_Category           Product_Sub_Category  Order_ID    Ship_Mode  \
# 0     OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS     36262  REGULAR AIR
# 1     OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS     36992  EXPRESS AIR
# 2     OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS     19524  REGULAR AIR
# 3     OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS     39330  EXPRESS AIR
# 4     OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS     20259  REGULAR AIR
# ...               ...                            ...       ...          ...
# 1675  OFFICE SUPPLIES         STORAGE & ORGANIZATION     34980  EXPRESS AIR
# 1676  OFFICE SUPPLIES         STORAGE & ORGANIZATION     30885  REGULAR AIR
# 1677  OFFICE SUPPLIES         STORAGE & ORGANIZATION      8803  REGULAR AIR
# 1678  OFFICE SUPPLIES         STORAGE & ORGANIZATION     36896  REGULAR AIR
# 1679  OFFICE SUPPLIES         STORAGE & ORGANIZATION     10562  REGULAR AIR
#
#        Ship_Date
# 0     28-07-2010
# 1     09-12-2009
# 2     15-01-2010
# 3     18-07-2010
# 4     25-05-2011
# ...          ...
# 1675  04-08-2010
# 1676  22-06-2010
# 1677  21-12-2012
# 1678  03-11-2009
# 1679  12-11-2009
#
# [1680 rows x 19 columns]

# %%
# Merging the orders table to create a master df
master_df = pd.merge(df_3,orders_df, how = 'inner', on = 'Ord_id')

master_df
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id   Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818  136.81      0.01
# 1     Ord_5446   Prod_6  SHP_7608  Cust_1818  164.02      0.03
# 2     Ord_3730  Prod_16  SHP_5175  Cust_1314  459.08      0.04
# 3     Ord_4506  Prod_16  SHP_6273  Cust_1544   92.02      0.07
# 4     Ord_1551  Prod_16  SHP_2145   Cust_531  184.77      0.00
# ...        ...      ...       ...        ...     ...       ...
# 1675  Ord_4549   Prod_1  SHP_6332  Cust_1530  297.85      0.04
# 1676  Ord_4758   Prod_1  SHP_6637  Cust_1638  448.10      0.10
# 1677  Ord_3339   Prod_1  SHP_4632  Cust_1180  257.41      0.09
# 1678  Ord_4604   Prod_1  SHP_6403  Cust_1522  234.24      0.09
# 1679  Ord_4424   Prod_1  SHP_6165  Cust_1519  994.04      0.03
#
#       Order_Quantity  Profit  Shipping_Cost  Product_Base_Margin  ...  \
# 0                 23  -30.51           3.60                 0.56  ...
# 1                 23  -47.64           6.15                 0.37  ...
# 2                 34   61.57           3.14                 0.60  ...
# 3                  9  -24.88           4.68                 0.59  ...
# 4                 29  -71.96           5.30                 0.55  ...
# ...              ...     ...            ...                  ...  ...
# 1675               5  -69.89          19.99                 0.59  ...
# 1676              35  -15.07           4.51                 0.59  ...
# 1677              43 -131.08           4.69                 0.68  ...
# 1678              24 -151.80           9.45                 0.60  ...
# 1679              10 -335.06          35.00                  NaN  ...
#
#        Region Customer_Segment Product_Category  \
# 0        WEST        CORPORATE  OFFICE SUPPLIES
# 1        WEST        CORPORATE  OFFICE SUPPLIES
# 2      PRARIE        CORPORATE  OFFICE SUPPLIES
# 3       YUKON        CORPORATE  OFFICE SUPPLIES
# 4     ONTARIO        CORPORATE  OFFICE SUPPLIES
# ...       ...              ...              ...
# 1675    YUKON        CORPORATE  OFFICE SUPPLIES
# 1676     WEST        CORPORATE  OFFICE SUPPLIES
# 1677   PRARIE        CORPORATE  OFFICE SUPPLIES
# 1678    YUKON        CORPORATE  OFFICE SUPPLIES
# 1679    YUKON        CORPORATE  OFFICE SUPPLIES
#
#                Product_Sub_Category Order_ID_x    Ship_Mode   Ship_Date  \
# 0     SCISSORS, RULERS AND TRIMMERS      36262  REGULAR AIR  28-07-2010
# 1                             PAPER      36262  EXPRESS AIR  28-07-2010
# 2     SCISSORS, RULERS AND TRIMMERS      36992  EXPRESS AIR  09-12-2009
# 3     SCISSORS, RULERS AND TRIMMERS      19524  REGULAR AIR  15-01-2010
# 4     SCISSORS, RULERS AND TRIMMERS      39330  EXPRESS AIR  18-07-2010
# ...                             ...        ...          ...         ...
# 1675         STORAGE & ORGANIZATION      23366  REGULAR AIR  19-11-2010
# 1676         STORAGE & ORGANIZATION      50950  EXPRESS AIR  30-12-2012
# 1677         STORAGE & ORGANIZATION      25601  REGULAR AIR  06-01-2009
# 1678         STORAGE & ORGANIZATION      30885  REGULAR AIR  22-06-2010
# 1679         STORAGE & ORGANIZATION      10562  REGULAR AIR  12-11-2009
#
#      Order_ID_y  Order_Date  Order_Priority
# 0         36262  27-07-2010   NOT SPECIFIED
# 1         36262  27-07-2010   NOT SPECIFIED
# 2         36992  07-12-2009          MEDIUM
# 3         19524  14-01-2010        CRITICAL
# 4         39330  17-07-2010        CRITICAL
# ...         ...         ...             ...
# 1675      23366  19-11-2010   NOT SPECIFIED
# 1676      50950  30-12-2012   NOT SPECIFIED
# 1677      25601  05-01-2009          MEDIUM
# 1678      30885  21-06-2010            HIGH
# 1679      10562  11-11-2009   NOT SPECIFIED
#
# [1680 rows x 22 columns]

# %%
master_df.shape
# Out:
# (1680, 22)

# %% [markdown]
# ### Chain of merge

# %%
# Syntax : df_1.merge(df_2,on 'ID').merge(df_3, on = 'ID').merge(df_4, on 'ID')

# %% [markdown]
# Similary, you can perform left, right and outer merges (joins) by using the argument ```how = 'left' / 'right' / 'outer'```.

# %% [markdown]
# ### Concatenating Dataframes
#
# Concatenation is much more straightforward than merging. It is used when you have dataframes having the same columns and want to append them (pile(heap or stack) one on top of the other), or having the same rows and want to append them side-by-side.
#
# #### Concatenating Dataframes Having the Same columns
#
# Say you have two dataframes having the same columns, like so:

# %%
# dataframes having the same columns

df1 = pd.DataFrame({"Name" : ['Raju','Somu','Mouni'],
                    'Age' : [21,23,25],
                    'Gender' : ['M','M','F']}
                  )

df2 = pd.DataFrame({"Name" : ['Yash','Bunny','Manu'],
                    'Age' : [26,22,28],
                    'Gender' : ['M','M','F']}
                  )

# %%
df1
# Out:
#     Name  Age Gender
# 0   Raju   21      M
# 1   Somu   23      M
# 2  Mouni   25      F

# %%
df2
# Out:
#     Name  Age Gender
# 0   Yash   26      M
# 1  Bunny   22      M
# 2   Manu   28      F

# %%
# To concatenate them, one on top of the other, you can use pd.concat
# The first argument is a sequence (list) of dataframes
# axis = 0 indicates that we want to concat along the row axis

pd.concat([df1,df2], axis =0)   # Row Concatenation (axis = 0)
# Out:
#     Name  Age Gender
# 0   Raju   21      M
# 1   Somu   23      M
# 2  Mouni   25      F
# 0   Yash   26      M
# 1  Bunny   22      M
# 2   Manu   28      F

# %%
pd.concat([df1,df2], axis = 1)  # Column Concatenation (axis = 1)
# Out:
#     Name  Age Gender   Name  Age Gender
# 0   Raju   21      M   Yash   26      M
# 1   Somu   23      M  Bunny   22      M
# 2  Mouni   25      F   Manu   28      F

# %%
# A useful and intuitive alternative to concat along the rows is the append() function
# It concatenates along the rows


# df1.append(df2) (Old_Version) # In new_version Removed.

# %% [markdown]
# #### Concatenating Dataframes Having the Same Rows
#
# You may also have dataframes having the same rows but different columns (and having no common columns). In this case, you may want to concat them side-by-side. For e.g.:

# %%
df1
# Out:
#     Name  Age Gender
# 0   Raju   21      M
# 1   Somu   23      M
# 2  Mouni   25      F

# %%
df2
# Out:
#     Name  Age Gender
# 0   Yash   26      M
# 1  Bunny   22      M
# 2   Manu   28      F

# %%
pd.concat([df1,df2], axis = 1)
# Out:
#     Name  Age Gender   Name  Age Gender
# 0   Raju   21      M   Yash   26      M
# 1   Somu   23      M  Bunny   22      M
# 2  Mouni   25      F   Manu   28      F

# %%
# To join the two dataframes, use axis = 1 to indicate joining along the columns axis
# The join is possible because the corresponding rows have the same indices

# %% [markdown]
# Note that you can also use the ```pd.concat()``` method to merge dataframes using common keys, though here we will not discuss that. For simplicity, we have used the ```pd.merge()``` method for database-style merging and ```pd.concat()``` for appending dataframes having no common columns.

# %% [markdown]
# #### Performing Arithmetic Operations on two or more dataframes
#
# We can also perform simple arithmetic operations on two or more dataframes. Below are the stats for IPL 2018 and 2017.

# %%
# Teamwise stats for IPL 2018

df7 = pd.DataFrame({'Name' : ['Raju','Somu','Mouni'],
                    'Age' : [21,23,25],
                    'Gender' : [2,2,1]}
                  )

df7.set_index('Name', inplace = True)
# Set the 'IPL Team' column as the index to perform arithmetic operations on the other rows using the team as reference

df7
# Out:
#        Age  Gender
# Name
# Raju    21       2
# Somu    23       2
# Mouni   25       1

# %%
# Similarly, we have the stats for IPL 2017

df8 = pd.DataFrame({"Name" : ['Yash','Bunny','Manu'],
                    'Age' : [26,22,28],
                    'Gender' : [2,2,1]}
                  )

df8.set_index('Name', inplace = True)

df8
# Out:
#        Age  Gender
# Name
# Yash    26       2
# Bunny   22       2
# Manu    28       1

# %%
# Simply add the two DFs using the add opearator

df7 + df8   # we dont have a luxury by simple using '+' Operator, lets see how
# Out:
#        Age  Gender
# Name
# Bunny  NaN     NaN
# Manu   NaN     NaN
# Mouni  NaN     NaN
# Raju   NaN     NaN
# Somu   NaN     NaN
# Yash   NaN     NaN

# %% [markdown]
# Notice that there are a lot of NaN values. This is because some teams which played in IPL 2017 were not present in IPL 2018. In addition, there were also new teams present in IPL 2018. We can handle these NaN values by using `df.add()` instead of the simple add operator. Let's see how.

# %%
# The fill_value argument inside the df.add() function replaces all the NaN values in the two dataframes w.r.t. each other with zero.

Total = df7.add(df8, fill_value=0)

Total
# Out:
#         Age  Gender
# Name
# Bunny  22.0     2.0
# Manu   28.0     1.0
# Mouni  25.0     1.0
# Raju   21.0     2.0
# Somu   23.0     2.0
# Yash   26.0     2.0

# %% [markdown]
# Also notice how the resultant dataframe is sorted by the index, i.e. 'IPL Team' alphabetically.

# %%
# Creating a new column - 'Win Percentage'

Total['Win Percentage'] = Total['Gender']/Total['Age']

Total['Win Percentage']
# Out:
# Name
# Bunny    0.090909
# Manu     0.035714
# Mouni    0.040000
# Raju     0.095238
# Somu     0.086957
# Yash     0.076923
# Name: Win Percentage, dtype: float64

# %%
Total
# Out:
#         Age  Gender  Win Percentage
# Name
# Bunny  22.0     2.0        0.090909
# Manu   28.0     1.0        0.035714
# Mouni  25.0     1.0        0.040000
# Raju   21.0     2.0        0.095238
# Somu   23.0     2.0        0.086957
# Yash   26.0     2.0        0.076923

# %%
# Sorting to determine the teams with most number of wins. If the number of wins of two teams are the same, sort by the win percentage.

Total.sort_values(by = (['Gender', 'Win Percentage']), ascending = False)
# Out:
#         Age  Gender  Win Percentage
# Name
# Raju   21.0     2.0        0.095238
# Bunny  22.0     2.0        0.090909
# Somu   23.0     2.0        0.086957
# Yash   26.0     2.0        0.076923
# Mouni  25.0     1.0        0.040000
# Manu   28.0     1.0        0.035714

# %% [markdown]
# Apart from add(), there are also other operator-equivalent mathematical functions that you can use on Dataframes. Below is a list of all the functions that you can use to perform operations on two or more dataframes
# -  `add()`: +
# -  `sub()`: -
# -  `mul()`: *
# -  `div()`: /
# -  `floordiv()`: //
# -  `mod()`: %
# -  `pow()`: **
